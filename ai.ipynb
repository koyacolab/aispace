# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# from google.colab import drive
# drive.mount('/content/gdrive/')

# import os

# # !pip install fire
# # !pip install tqdm

# home_dir = '/content/gdrive/My Drive/A0/aispace'
# os.chdir(home_dir)
# !pwd

# import os
# # Get the current working directory
# current_directory = os.getcwd()
# print(current_directory)

# import shutil
# import os

# %%
# !pip install rasterio
# !pip install accelerate
# !pip install peft
# !pip install transformers
# # !pip install transformers==4.33.0
# !pip install datasets
# # !python3 -m pip install --upgrade pip
# # !pip install Sophia-Optimizer

# %%
KAGGLE = False
if KAGGLE == True:
    # Define the input and output directories
    input_directory  = '/kaggle/input/aidataset'  # Replace with the path to your input directory
    output_directory = '/kaggle/working'  # Replace with the path to your output directory

    def input_copy(input_directory, output_directory):
        # Get a list of files in the input directory
        files_to_copy = os.listdir(input_directory)
        # Iterate through the files and copy them to the output directory
        for file_name in files_to_copy:
            # Create the full paths for the source and destination
            source_file = os.path.join(input_directory, file_name)
            destination_file = os.path.join(output_directory, file_name)

            # Copy the file from the source to the destination
            shutil.copy(source_file, destination_file)

        # Get a list of files in the input directory
        files = os.listdir(output_directory)
        print(files)

    input_copy(input_directory, output_directory)

    source_directory  = '/kaggle/input/'  # Replace with the path to your input directory
    destination_directory = '/kaggle/working/input'  # Replace with the path to your output directory

    # Copy the source directory to the destination directory
    shutil.copytree(source_directory, destination_directory)

    input_copy(input_directory, output_directory)

# %%
# import sophia

# !pip install wandb

# wandb.login()

# %%
import numpy as np

import great
from great import GReaT

import pandas as pd

################################
import numpy as np

import pandas as pd

# all imports should go here

import numpy as np
import matplotlib.pyplot as plt
import rasterio as rio
from rasterio.plot import show

import sklearn
from sklearn.model_selection import train_test_split

import skimage.exposure

# access package for AWS access
# import boto3

import sys
import os
import subprocess
import datetime
import platform
import datetime

from tqdm import tqdm

# import ee
import h5py
import numpy as np
from datetime import datetime, timedelta  # Import timedelta here
import random
import pandas as pd

import time
import rasterio as rio
################################



from hlsdataset import HLSDataSet

import shutil

# Execute only once!
import os
import sys
sys.path.append("..")
os.chdir("..")

# %%
os.environ['TRANSFORMERS_NO_ADVISORY_WARNINGS'] = 'true'

# Get the current working directory
current_directory = os.getcwd()
print(current_directory)

print(f'NumPy version:{np.__version__}')
np.float = float # 'float32' # float
table_dtype = np.float  # 'int64'   # np.float  #'float32'
print(table_dtype)

hls_data = HLSDataSet(table_dtype = table_dtype)

#### clip 50x50 subdataset
# hls_data.clip_dataset(x1=50.0, y1=50.0, x2=100.0, y2=100.0)

doys = [171, 179, 187, 195, 203, 211, 219]
doys = [171, 179, 187, 203, 211, 219]
# doys = [203, 211, 219]
doys = [203, 211, 219]
df = hls_data._get_data_doys(doys = doys, SHOW=True)
display(df)

# df = hls_data._set_columns_name()
# display(df)

df1, df2 = hls_data._nan_9999()
# display(df1)
# display(df2)

df1, df2 = hls_data._set_clear_cloud()
# display(df1)
# display(df2)

data, nan, clear, cloud = hls_data._set_train_columns_name()

print('clear')
display(clear)

# train_data, test_data = hls_data._set_train_test_data(doy=211.0, x1=60.0, y1=40.0, x2=75.0, y2=55.0)

train_data, test_data = hls_data._set_train_test_data(doy=211.0, x1=45.0, y1=45.0, x2=50.0, y2=50.0)
# train_data, test_data = hls_data._set_timeseries_train_test_data(doy=211.0, x1=50.0, y1=50.0, x2=100.0, y2=100.0)

print('train_data')
display(train_data)
print('test_data')
display(test_data)
# display(data)
# display(nan)
# display(clear)
# display(cloud)

hls_data._to_impute()
hls_data._inference_train_test_data()
hls_data._inference_imshow()

# fn
# Out:
# /home
# NumPy version:1.26.1
# <class 'float'>
# PIDs is  9999
# [203]
# /home/aispace/hlsdataset.py:210: RuntimeWarning: invalid value encountered in cast
#   normalized_band = ((band - min_val) / (max_val - min_val) * 255).astype(np.uint8)
# [211]
# /home/aispace/hlsdataset.py:210: RuntimeWarning: invalid value encountered in cast
#   normalized_band = ((band - min_val) / (max_val - min_val) * 255).astype(np.uint8)
# [219]
#        Unnamed: 0    B01    B02    B03    B04     B05     B06     B07   B09  \
# 0         3387000  352.0  435.0  792.0  808.0  2829.0  2916.0  1915.0  12.0
# 1         3387001  380.0  492.0  842.0  911.0  2754.0  2861.0  1991.0  13.0
# 2         3387002  275.0  374.0  660.0  673.0  2509.0  2330.0  1446.0   9.0
# 3         3387003  205.0  289.0  562.0  550.0  2275.0  2100.0  1194.0   9.0
# 4         3387004  218.0  309.0  566.0  579.0  2141.0  1947.0  1101.0  12.0
# ...           ...    ...    ...    ...    ...     ...     ...     ...   ...
# 29995     3749435  262.0  338.0  591.0  576.0  1950.0  2081.0  1194.0   9.0
# 29996     3749436  271.0  350.0  606.0  577.0  2002.0  2068.0  1179.0   9.0
# 29997     3749437  266.0  345.0  597.0  566.0  2000.0  2089.0  1193.0  14.0
# 29998     3749438  268.0  348.0  596.0  573.0  2025.0  2122.0  1215.0  13.0
# 29999     3749439  261.0  348.0  612.0  582.0  2099.0  2118.0  1194.0  10.0
#
#           B10  ...  aero    SAA   SZA    VAA  VZA     X     Y  DOY      NDVI  \
# 0      2455.0  ...     1  14725  3342  22407   90  1500   925  203  0.555678
# 1      2443.0  ...     1  14725  3342  22422   90  1501   925  203  0.502865
# 2      2432.0  ...     1  14725  3342  22436   90  1502   925  203  0.576996
# 3      2421.0  ...     1  14725  3342  22451   90  1503   925  203  0.610619
# 4      2403.0  ...     1  14725  3342  22465   90  1504   925  203  0.574265
# ...       ...  ...   ...    ...   ...    ...  ...   ...   ...  ...       ...
# 29995  2765.0  ...     2  14999  3693  24386  119  1595  1024  219  0.543943
# 29996  2771.0  ...     2  14999  3693  24395  119  1596  1024  219  0.552540
# 29997  2775.0  ...     2  14999  3693  24403  119  1597  1024  219  0.558846
# 29998  2773.0  ...     2  14999  3693  24411  119  1598  1024  219  0.558891
# 29999  2763.0  ...     2  14999  3693  24419  120  1599  1024  219  0.565834
#
#         PID
# 0         0
# 1       100
# 2       200
# 3       300
# 4       400
# ...     ...
# 29995  9599
# 29996  9699
# 29997  9799
# 29998  9899
# 29999  9999
#
# [30000 rows x 27 columns]
# Change columns list: ['Unnamed: 0', 'B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B09', 'B10', 'B11', 'cirrus', 'cloud', 'adj_cloud', 'cloud_shadow', 'snow_ice', 'water', 'aero', 'SAA', 'SZA', 'VAA', 'VZA', 'X', 'Y', 'DOY', 'NDVI', 'PID']->['B02', 'B03', 'B04', 'B05', 'NDVI', 'X', 'Y', 'DOY', 'PID']
# clear
#          B02    B03    B04     B05      NDVI       X       Y    DOY     PID
# 0      382.0  687.0  639.0  3072.0  0.655618  1549.0   925.0  203.0  4900.0
# 1      352.0  684.0  554.0  3259.0  0.709415  1550.0   925.0  203.0  5000.0
# 2      283.0  587.0  483.0  2920.0  0.716133  1551.0   925.0  203.0  5100.0
# 3      286.0  567.0  478.0  2696.0  0.698803  1552.0   925.0  203.0  5200.0
# 4      315.0  578.0  496.0  3012.0  0.717218  1553.0   925.0  203.0  5300.0
# ...      ...    ...    ...     ...       ...     ...     ...    ...     ...
# 20360  338.0  591.0  576.0  1950.0  0.543943  1595.0  1024.0  219.0  9599.0
# 20361  350.0  606.0  577.0  2002.0  0.552540  1596.0  1024.0  219.0  9699.0
# 20362  345.0  597.0  566.0  2000.0  0.558846  1597.0  1024.0  219.0  9799.0
# 20363  348.0  596.0  573.0  2025.0  0.558891  1598.0  1024.0  219.0  9899.0
# 20364  348.0  612.0  582.0  2099.0  0.565834  1599.0  1024.0  219.0  9999.0
#
# [20365 rows x 9 columns]
# train_data
#          B02    B03    B04     B05      NDVI       X       Y    DOY     PID
# 0      382.0  687.0  639.0  3072.0  0.655618  1549.0   925.0  203.0  4900.0
# 1      352.0  684.0  554.0  3259.0  0.709415  1550.0   925.0  203.0  5000.0
# 2      283.0  587.0  483.0  2920.0  0.716133  1551.0   925.0  203.0  5100.0
# 3      286.0  567.0  478.0  2696.0  0.698803  1552.0   925.0  203.0  5200.0
# 4      315.0  578.0  496.0  3012.0  0.717218  1553.0   925.0  203.0  5300.0
# ...      ...    ...    ...     ...       ...     ...     ...    ...     ...
# 20360  338.0  591.0  576.0  1950.0  0.543943  1595.0  1024.0  219.0  9599.0
# 20361  350.0  606.0  577.0  2002.0  0.552540  1596.0  1024.0  219.0  9699.0
# 20362  345.0  597.0  566.0  2000.0  0.558846  1597.0  1024.0  219.0  9799.0
# 20363  348.0  596.0  573.0  2025.0  0.558891  1598.0  1024.0  219.0  9899.0
# 20364  348.0  612.0  582.0  2099.0  0.565834  1599.0  1024.0  219.0  9999.0
#
# [20365 rows x 9 columns]
# test_data
# Empty DataFrame
# Columns: [B02, B03, B04, B05, NDVI, X, Y, DOY, PID]
# Index: []
# to_impute:
#     B02  B03  B04  B05  NDVI       X      Y    DOY     PID
# 0   NaN  NaN  NaN  NaN   NaN  1500.0  925.0  203.0     0.0
# 1   NaN  NaN  NaN  NaN   NaN  1501.0  925.0  203.0   100.0
# 2   NaN  NaN  NaN  NaN   NaN  1502.0  925.0  203.0   200.0
# 3   NaN  NaN  NaN  NaN   NaN  1503.0  925.0  203.0   300.0
# 4   NaN  NaN  NaN  NaN   NaN  1504.0  925.0  203.0   400.0
# ..  ...  ...  ...  ...   ...     ...    ...    ...     ...
# 75  NaN  NaN  NaN  NaN   NaN  1527.0  985.0  211.0  2760.0
# 76  NaN  NaN  NaN  NaN   NaN  1524.0  986.0  211.0  2461.0
# 77  NaN  NaN  NaN  NaN   NaN  1525.0  986.0  211.0  2561.0
# 78  NaN  NaN  NaN  NaN   NaN  1526.0  986.0  211.0  2661.0
# 79  NaN  NaN  NaN  NaN   NaN  1527.0  986.0  211.0  2761.0
#
# [9635 rows x 9 columns]

# %%
#### CODE DATA 4 TRAIN #####################################
train_columns_list = ['B02', 'B03', 'B04', 'PID', 'DOY']
# train_columns_list = ['B03', 'PID', 'DOY']
data = train_data[train_columns_list].copy()

display(data)

# # Create a new DataFrame with four columns
# data = data.melt(id_vars=['PID', 'DOY'], value_vars=['B02', 'B03', 'B04'],
#                     var_name='BNAME', value_name='BAND')

# data['BNAME'] = data['BNAME'].astype(str)
# #############################################################

# # Get only trainable columns ###########################
# train_columns_list = ['DOY', 'PID', 'BNAME', 'BAND']

# data = data[train_columns_list].copy()

# # data = data.astype(table_dtype)
# print(data.dtypes.tolist())
# # Reset the index to remove it
# data = data.reset_index(drop=True)
# # train_data.columns = final_columns_list
# print(f'Code data 4 trainable is for {train_columns_list}')
# display(data)

# print('Ready for train...')
# Out:
#          B02    B03    B04     PID    DOY
# 0      382.0  687.0  639.0  4900.0  203.0
# 1      352.0  684.0  554.0  5000.0  203.0
# 2      283.0  587.0  483.0  5100.0  203.0
# 3      286.0  567.0  478.0  5200.0  203.0
# 4      315.0  578.0  496.0  5300.0  203.0
# ...      ...    ...    ...     ...    ...
# 20360  338.0  591.0  576.0  9599.0  219.0
# 20361  350.0  606.0  577.0  9699.0  219.0
# 20362  345.0  597.0  566.0  9799.0  219.0
# 20363  348.0  596.0  573.0  9899.0  219.0
# 20364  348.0  612.0  582.0  9999.0  219.0
#
# [20365 rows x 5 columns]

# %%
# #### TRAIN TOKENIZER FOR HLS DATA ################################################
# #### TRAIN ONCE AND COMMENT FOR AVOID FORKING TOKENIZER ##########################

EXP_NAME = f'A0[RGB_TOK[ai]_Lora]'
EXP_NAME = f'A0[RGB_TOK[ai60]]'

from huggingface_hub import notebook_login

# notebook_login()

ReTRAIN_TOKENIZER = False
if ReTRAIN_TOKENIZER == True:
    def _get_synth_data():
        BAND = [b for b in range(0, 10)]
        PID  = [p for p in range(0, 10)]
        DOY  = [d for d in range(0, 10)]   
        # BNAME = ['B02', 'B03', 'B04']
        # Create a DataFrame with specified column names
        # synth_data = pd.DataFrame(list(zip(BAND, PID, DOY)), columns=['BAND', 'PID', 'DOY'])
        synth_data = pd.DataFrame(list(zip(BAND, BAND, BAND, PID, DOY)), columns=['B02', 'B03', 'B04', 'PID', 'DOY'])

        # # Create a list of tuples with all possible combinations of DOY and PID
        # synth_data = [(d, p, b) for d in DOY for p in PID for b in BAND]
        # # Create a DataFrame from the data
        # synth_data = pd.DataFrame(synth_data, columns=["DOY", "PID", "B03"])
        return synth_data.astype(table_dtype)
    
    synth_data = _get_synth_data()

    synth_data = data
    
    # Display the DataFrame
    display(synth_data)
    
    from transformers import AutoTokenizer
    from aitokenizer import TrainTokenizer, TrainCorpus, PreTrainTokenizer
    
    old_tokenizer = AutoTokenizer.from_pretrained('distilgpt2')
    old_tokenizer.pad_token = old_tokenizer.eos_token
    
    data_corpus = TrainCorpus(synth_data)._get_training_corpus()

    sample = next(data_corpus)[0]
    print('L8 data:', sample)
    
    tokens = old_tokenizer.tokenize(sample)
    print('old_tokenizer:', len(tokens), tokens)
    # print(old_tokenizer(sample).tokens())

    digits_tok = [str(x) for x in range(0,10)]
    # spec_tok = ['B02', 'B03', 'B04']
    # print()
    # new_tokenizer = TrainTokenizer(synth_data, sample, old_tokenizer)._train(special_tokens=train_columns_list)
    new_tokenizer = PreTrainTokenizer(data, old_tokenizer)._train(special_tokens=digits_tok+['is', 'B', 'DOY', 'PID']) #digits_tok+
    # new_tokenizer = PreTrainTokenizer(data, old_tokenizer)._train(special_tokens=train_columns_list+digits_tok)
    
    # print(new_tokenizer(sample).tokens())
    tokens = new_tokenizer.tokenize(sample)
    print('aispace-tokenizer:', len(tokens), tokens)
    
    new_tokenizer.save_pretrained(f"{EXP_NAME}/aispace-tokenizer")

    print('Tokenizer trained, COMMENT & RELOAD Tokenizer Trainer...')

# else:
#     new_tokenizer = AutoTokenizer.from_pretrained(f"{EXP_NAME}/aispace-tokenizer")
#     new_tokenizer.pad_token = new_tokenizer.eos_token

#     data_corpus = TrainCorpus(data)._get_training_corpus()

#     sample = next(data_corpus)[0]
#     print('L8 data:', sample)

#     tokens = old_tokenizer.tokenize(sample)
#     print('old_tokenizer:', tokens)

    fn

# %%
# Split the DataFrame into training and test DataFrames
# train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
# train_data = train_data.reset_index(drop=True)
# display(train_data)
# test_data = test_data.reset_index(drop=True)
# display(test_data)
# fn

# EXP_NAME = f'A0[ONE_TOK[ai]]'
# EXP_NAME = f'A0[ONE_TOK[gpt]]'

step_checkpoint_list = [7000, 105000, 82000, 32000, 22000, 112000, 112000, 112000]
step_checkpoint_list = [112000, 32000, 21000]
step_checkpoint_list = [20000, 194000]
step_checkpoint_list = [24000, 194000]
step_checkpoint_list = [175000, ]


TRAINER_RUN = 1
RESUME_FROM_CHECKPOINT = False

if TRAINER_RUN == 0:
    load_model_path = 'distilgpt2'
    experiment_dir = f"{EXP_NAME}/run[{TRAINER_RUN}]"
elif TRAINER_RUN > 0:
    # before = pd.read_csv(f'{EXP_NAME}/run[{TRAINER_RUN-1}].csv')
    # load_model_path = before['experiment_dir'][0] + f'/checkpoint-{step_checkpoint}'
    if RESUME_FROM_CHECKPOINT == True:
        step_checkpoint = step_checkpoint_list[TRAINER_RUN]
        load_model_path = f'{EXP_NAME}/run[{TRAINER_RUN}]' + f'/checkpoint-{step_checkpoint}'
        print(f'Resume from checkpoint:{load_model_path}')
    else:
        step_checkpoint = step_checkpoint_list[TRAINER_RUN-1]
        load_model_path = f'{EXP_NAME}/run[{TRAINER_RUN-1}]' + f'/checkpoint-{step_checkpoint}'
    experiment_dir  = f"{EXP_NAME}/run[{TRAINER_RUN}]"

###########################################################
#### TRAINER HYPERPARAMETERS #############################
save_steps = 1000
logging_steps = 200

epochs = 1000
max_steps = 175000 # if -1 max_steps ignored 

batch_size = 280  
batch_size = 180 #for 60 tokens

learning_rate = 1e-4
lr_scheduler_type = 'constant'
lr_scheduler_type = 'cosine'
num_cycles = 5

warmup_steps = 25000

optimizer = 'sophia'
###########################################################
##### SET experiment_dir & efficient_finetuning #######################
efficient_finetuning = ''  #'lora'
##########################################################
###########################################################

TRAINER_DICT = pd.DataFrame({'EXP_NAME' : EXP_NAME}, index = [TRAINER_RUN])    # dict()
TRAINER_DICT['TRAINER_RUN'] = TRAINER_RUN
TRAINER_DICT['table_dtype'] = table_dtype
TRAINER_DICT['experiment_dir'] = experiment_dir
TRAINER_DICT['save_steps'] = save_steps
TRAINER_DICT['logging_steps'] = logging_steps
TRAINER_DICT['epochs'] = epochs
TRAINER_DICT['max_steps'] = max_steps
TRAINER_DICT['batch_size'] = batch_size
TRAINER_DICT['learning_rate'] = learning_rate
TRAINER_DICT['lr_scheduler_type'] = lr_scheduler_type
TRAINER_DICT['warmup_steps'] = warmup_steps
TRAINER_DICT['num_cycles'] = num_cycles
TRAINER_DICT['optimizer'] = optimizer
TRAINER_DICT['fp16'] = True

display(pd.DataFrame.from_dict(TRAINER_DICT))

print('experiment_dir :', experiment_dir)
print('load_model_path:', load_model_path)

# Get the current CPU time in seconds since the epoch
current_time = int(time.time())
# Use the current time as a seed for a random number generator
random_seed_state = current_time  # You can use this random_state for various random processes

model = GReaT(llm=load_model_path,
              # tokenizer=load_model_path,
              tokenizer=f"{EXP_NAME}/aispace-tokenizer",
              # tokenizer=load_model_path,
              # auto_find_batch_size=True,
              batch_size=batch_size, epochs=epochs, max_steps = max_steps,
              logging_steps=logging_steps, save_steps=save_steps,
              # evaluation_strategy='steps',
              logging_first_step=True,
              save_total_limit=2,
              prediction_loss_only=True,
              experiment_dir=experiment_dir,
              dataloader_num_workers=2,
              efficient_finetuning = efficient_finetuning,
              learning_rate=learning_rate,
              lr_scheduler_type=lr_scheduler_type,
              warmup_steps = warmup_steps,
              num_cycles = num_cycles,
              # warmup_ratio=0.05,
              seed=current_time,
              data_seed=current_time+int(time.time()),
              # optim=TRAINER_DICT['optimizer'],
              fp16 = True,            #### comment for Ampere, for Volta
              # torch_compile=True,   #### uncomment for Ampere
              # bf16=True,            #### uncomment for Ampere
              # report_to='none'
              )

print(f'----------- Model architecture, efficient_finetuning: {efficient_finetuning} -----------------------')
print(model.model)
print(f'----------------------------------------------------------------------------------------------------')
# fn

if RESUME_FROM_CHECKPOINT == True:
    model.fit(data=data, resume_from_checkpoint=True)
else:
    model.fit(data=data)
# model.fit(data=train_data, test_data=test_data)

model.save(f'{experiment_dir}/model')

TRAINER_DICT.to_csv(f'{experiment_dir}.csv')
# Out:
#             EXP_NAME  TRAINER_RUN      table_dtype            experiment_dir  \
# 1  A0[RGB_TOK[ai60]]            1  <class 'float'>  A0[RGB_TOK[ai60]]/run[1]
#
#    save_steps  logging_steps  epochs  max_steps  batch_size  learning_rate  \
# 1        1000            200    1000     175000         180         0.0001
#
#   lr_scheduler_type  warmup_steps  num_cycles optimizer  fp16
# 1            cosine         25000           5    sophia  True
# experiment_dir : A0[RGB_TOK[ai60]]/run[1]
# load_model_path: A0[RGB_TOK[ai60]]/run[0]/checkpoint-175000
# ----------- Model architecture, efficient_finetuning:  -----------------------
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )
# ----------------------------------------------------------------------------------------------------
# WARNING:accelerate.utils.other:Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Optimiser: Sophia
# self.train_hyperparameters: {'logging_steps': 200, 'save_steps': 1000, 'logging_first_step': True, 'save_total_limit': 2, 'prediction_loss_only': True, 'dataloader_num_workers': 2, 'learning_rate': 0.0001, 'lr_scheduler_type': 'cosine', 'warmup_steps': 25000, 'seed': 1699798168, 'data_seed': 3399596336, 'fp16': True}
# total_train_steps calculated: 175000 20365 180
# warmup_steps: 25000
# lr_scheduler_type: cosine
# wandb: Currently logged in as: koya09ua (koyaua). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/wandb/run-20231112_220936-ug3f5apz</code>
# Syncing run <strong><a href='https://wandb.ai/koyaua/huggingface/runs/ug3f5apz' target="_blank">ethereal-mountain-251</a></strong> to <a href='https://wandb.ai/koyaua/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/koyaua/huggingface' target="_blank">https://wandb.ai/koyaua/huggingface</a>
#  View run at <a href='https://wandb.ai/koyaua/huggingface/runs/ug3f5apz' target="_blank">https://wandb.ai/koyaua/huggingface/runs/ug3f5apz</a>
#     <div>
#
#       <progress value='4255' max='175000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  4255/175000 15:31 < 10:23:20, 4.57 it/s, Epoch 37.32/1536]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.525200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.550600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.398600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.154200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.863300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.592800</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.507400</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.481600</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.466800</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.455300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.446200</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.440400</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.435000</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.430800</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.427200</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.423500</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.421300</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.418100</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.415600</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.412600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.410200</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.407900</td>
#     </tr>
#   </tbody>
# </table><p>
# wandb: Network error (TransientError), entering retry loop.

# %%
from google.colab import runtime
runtime.unassign()

# %%
fn

# %% [raw]
# fn
